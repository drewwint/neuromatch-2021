# %% [markdown]
# <a href="https://colab.research.google.com/github/drewwint/neuromatch-2021/blob/Project/Importing-nilearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nilearn

import nilearn
# Out:
# ...
#      |████████████████████████████████| 4.9MB 8.7MB/s
# ...
